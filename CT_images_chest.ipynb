# %% [markdown]
# 依赖

# %%
import dicom
import os

# %% [markdown]
# 引入路径

# %%
datadir = "/mnt/vdb1/sample_images/"
os.listdir(datadir)[0]
# Out:
# '0c9d8314f9c69840e25febabb1229fa4'

# %%
ds = dicom.read_file("/mnt/vdb1/sample_images/0c9d8314f9c69840e25febabb1229fa4/798b2a137d60812670b75b944b0ac919.dcm")

# %%
ds.PatientName
ds.dir("setup")
ds
# Out:
# (0008, 0000) Group Length                        UL: 320
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.7009.9004.288205993362152259454369141501
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 103e) Series Description                  LO: 'Axial'
# (0010, 0000) Group Length                        UL: 60
# (0010, 0010) Patient's Name                      PN: '0c9d8314f9c69840e25febabb1229fa4'
# (0010, 0020) Patient ID                          LO: '0c9d8314f9c69840e25febabb1229fa4'
# (0010, 0030) Patient's Birth Date                DA: '19000101'
# (0018, 0060) KVP                                 DS: ''
# (0020, 0000) Group Length                        UL: 394
# (0020, 000d) Study Instance UID                  UI: 2.25.98888670383004086987645641136824594925503511590518072086703
# ...

# %%
import pylab
pylab.imshow(ds.pixel_array, cmap=pylab.cm.bone)

# %%
pylab.show()

# %%
import glob
files = glob.glob(datadir + '*/*.dcm')
len(files)
# Out:
# 3604
